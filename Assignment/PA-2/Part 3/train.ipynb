# %% [markdown]
# # Part Ⅲ: PyTorch RNN
#
# ## Task Ⅰ: PyTorch RNN Implementation

# %%
# %run train.py --input_length 5 --train_steps 2000
# Out:
# Epoch 0
# Train Accuracy: 0.055 	 Train Loss: 2.308	Test Accuracy: 0.102 	 Test Loss: 0.018	Avg Time Cost: 0.006s
# Epoch 10
# Train Accuracy: 0.086 	 Train Loss: 2.315	Test Accuracy: 0.106 	 Test Loss: 0.018	Avg Time Cost: 0.003s
# Epoch 20
# Train Accuracy: 0.203 	 Train Loss: 2.303	Test Accuracy: 0.190 	 Test Loss: 0.018	Avg Time Cost: 0.003s
# Epoch 30
# Train Accuracy: 0.188 	 Train Loss: 2.280	Test Accuracy: 0.213 	 Test Loss: 0.017	Avg Time Cost: 0.003s
# Epoch 40
# Train Accuracy: 0.297 	 Train Loss: 2.263	Test Accuracy: 0.218 	 Test Loss: 0.017	Avg Time Cost: 0.003s
# Epoch 50
# Train Accuracy: 0.273 	 Train Loss: 2.250	Test Accuracy: 0.294 	 Test Loss: 0.017	Avg Time Cost: 0.003s
# Epoch 60
# Train Accuracy: 0.242 	 Train Loss: 2.234	Test Accuracy: 0.302 	 Test Loss: 0.017	Avg Time Cost: 0.003s
# Epoch 70
# Train Accuracy: 0.266 	 Train Loss: 2.220	Test Accuracy: 0.307 	 Test Loss: 0.017	Avg Time Cost: 0.003s
# Epoch 80
# ...

# %% [markdown]
# ## Part Ⅱ: RNN Experiment

# %%
# %run train.py --input_length 2 --train_steps 2000 --quiet

# %%
# %run train.py --input_length 3 --train_steps 2000 --quiet

# %%
# %run train.py --input_length 4 --train_steps 2000 --quiet

# %%
# %run train.py --input_length 5 --train_steps 2000 --quiet

# %%
# %run train.py --input_length 6 --train_steps 2000 --quiet

# %%
# %run train.py --input_length 7 --train_steps 2000 --quiet

# %%
# %run train.py --input_length 8 --train_steps 2000 --quiet

# %%
# %run train.py --input_length 9 --train_steps 2000 --quiet

# %%
# %run train.py --input_length 10 --train_steps 2000 --quiet
