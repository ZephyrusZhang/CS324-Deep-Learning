# %% [markdown]
# # Part Ⅲ: PyTorch RNN
#
# ## Task Ⅰ: PyTorch RNN Implementation

# %%
# %run train.py --input_length 5 --train_steps 2000
# Out:
# Epoch 0
# Train Accuracy: 0.078 	 Train Loss: 2.303	Test Accuracy: 0.101 	 Test Loss: 0.018	Avg Time Cost: 0.297s
# Epoch 10
# Train Accuracy: 0.109 	 Train Loss: 2.311	Test Accuracy: 0.099 	 Test Loss: 0.018	Avg Time Cost: 0.046s
# Epoch 20
# Train Accuracy: 0.133 	 Train Loss: 2.309	Test Accuracy: 0.103 	 Test Loss: 0.018	Avg Time Cost: 0.025s
# Epoch 30
# Train Accuracy: 0.125 	 Train Loss: 2.307	Test Accuracy: 0.107 	 Test Loss: 0.018	Avg Time Cost: 0.018s
# Epoch 40
# Train Accuracy: 0.203 	 Train Loss: 2.303	Test Accuracy: 0.183 	 Test Loss: 0.018	Avg Time Cost: 0.015s
# Epoch 50
# Train Accuracy: 0.227 	 Train Loss: 2.289	Test Accuracy: 0.197 	 Test Loss: 0.017	Avg Time Cost: 0.012s
# Epoch 60
# Train Accuracy: 0.227 	 Train Loss: 2.278	Test Accuracy: 0.200 	 Test Loss: 0.017	Avg Time Cost: 0.011s
# Epoch 70
# Train Accuracy: 0.180 	 Train Loss: 2.270	Test Accuracy: 0.238 	 Test Loss: 0.017	Avg Time Cost: 0.010s
# Epoch 80
# ...

# %% [markdown]
# ## Part Ⅱ: RNN Experiment

# %%
# %run train.py --input_length 3 --train_steps 10000

# %%
# %run train.py --input_length 5 --train_steps 10000

# %%
# %run train.py --input_length 7 --train_steps 10000

# %%
# %run train.py --input_length 10 --train_steps 10000
