# %%
import seaborn as sns

from train_mlp_numpy import *

x, y = make_moons(n_samples=1000, shuffle=True, noise=0)
sns.scatterplot(x=x[:, 0], y=x[:, 1], hue=y, markers='o', s=25, edgecolor='k', legend=False).set_title('Data')
plt.show()

# %%
x_train, x_test, y_train, y_test = make_data(0.05)
sns.scatterplot(x=x_train[:, 0], y=x_train[:, 1], hue=y_train[:, 0], markers='o', s=25, edgecolor='k', legend=False)
plt.show()

# %%
main()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16236\451043146.py in <module>
# ----> 1 main()
#
# D:\File\Project\Pycharm\CS324-Deep-Learning\Assignment\PA-1\Part 2\train_mlp_numpy.py in main()
#      76         for i in range(batch_size):
#      77             i = i if method == 'BGD' else np.random.randint(0, batch_size)
# ---> 78             x, y = x_train[i], y_train[i]
#      79             mlp.zero_grad()
#      80
#
# D:\File\Project\Pycharm\CS324-Deep-Learning\Assignment\PA-1\Part 2\train_mlp_numpy.py in train()
#      50         y_hat = mlp.forward(x)
#      51         loss += criterion.forward(y_hat, y)
# ---> 52         np.append(predict, y_hat)
#      53     return accuracy(predict, label), loss / len(data)
#      54
#
# AttributeError: 'NoneType' object has no attribute 'dnn_hidden_units'
